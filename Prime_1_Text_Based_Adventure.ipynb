# %% [markdown]
# <a href="https://colab.research.google.com/github/YSHS-APCSP-2526/text-based-adventure-213425-a11y/blob/main/Prime_1_Text_Based_Adventure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Requirements for text based adventure
# 1. You must have at least 2 different "paths" that are at least 4 decisions in length
# 2. Include an element of randomness (from the random library)
# 3. Include a list that is core to the text based adventure
# 4. Include a function that is called within your program that includes a while loop, and a parameter that influences a conditional statement in your function.
# 5. Commented Code.
# 6. A [digital flowchart](https://docs.google.com/document/d/1p2k3wL6gzjYWBuWxwEQptmbbOZZNsQrthlC12SNtYgY/edit?usp=sharing) that follows accepted symbols for representing code. You can use google slides or [draw.io](https://www.drawio.com/) for the flowchart.

# %%
import random

OldMan_dialogue = [
    "currency in this world is called Berries",
    "some swords are cursed in this world they will always has a purple tint or a fear feeling",
    "you are currently in the East Blue, Shimotsuki Village",
    "this world has 3 sea's, they're called the first world, grand line, and the new world",
    "Haki in this world in like human armor, made of human will",
    "The marines is the this world is like the world's police",
    "The celestial dragons are the rulers of the world, they're beyond kings"

]

print(random.choice(OldMan_dialogue))

print("I got a challenge for you, fight me and I will see if you're worthy of moving of with your travels or if you need training, ... *looks at you with depth* actually i'm not giving you a choice in the matter, [fight him in the future or learn more info]")

#Click this to learn info about the go game
# Out:
# The marines is the this world is like the world's police
# I got a challenge for you, fight me and I will see if you're worthy of moving of with your travels or if you need training, ... *looks at you with depth* actually i'm not giving you a choice in the matter, [fight him or learn more info]

# %%
def responseValidator(response):
  while response !="yes" and response !="no":
    response = input("ONLY WORDS, yes or no:  ")
  return response

def responseValidator1(response):
  while response !="keep it" and response !="sell it":
    response = input("ONLY WORDS, keep it or sell it:  ")
  return response

def intro():
  response1 = input("You approach a cave, do you enter? yes or no: ")
  response1 = responseValidator(response1)
  return response1

def chioce1_BoringEnding(response):
  if response == "yes":
    print("You begin to feel a hint of fear... bats fly out the cave *You walked in and explored*")
  else:
    print("You kept moving and contined your normal life. Thank you for playing! jk you keep moving on")

def main():
  response = intro()
  chioce1_BoringEnding(response)

main()

def intro2():
  response2 = input("you found a wicked blade, you pick it up ... you saw a portal do you enter? yes or no:  ")
  response1 = responseValidator(response2)
  return response1

def chioce2(response2):
  if response2 == "yes":
    print("you jumped into a the priate like world")
  else:
    print("A boulder forced you to jump in or you would have died")

def main2():
  response2 = intro2()
  chioce2(response2)

main2()

def intro3():
  response3 = input("you crashed landed onto a nearby a village but your landing was slicence from trees ... the blade you have grabed from early turned into a cursed legendary blade do you keep it or sell it to a sword dealer in the nearby village?:  ")
  response1 = responseValidator1(response3)
  return response1

def chioce3(response3):
  if response3 == "keep it":
    print("You entered the village asking around for info about your current statues, you find a man that has travel around the world, you may ask him anything.")
  if response3 == "sell it":
    print("you went to the sword dealer, buying a new great level sword and in the village and in it sold for 10 million Berries and you ask around for info about your current statues, you find a man that has travel around the world, you may ask him anything")

inventory = []

item = input("cursed legendary blade. keep it? (yes/no): ")
if item.lower() == "yes":
    inventory.append("cursed legendary blade")
    print("You added a cursed legendary blade to your inventory!")
else:
    inventory.append("10000000 Berries")
    inventory.append("Great Sword")
    print("You added a Great Sword and 10000000 Berries to your inventory!")

def main3():
  response3 = intro3()
  chioce3(response3)

main3()

if "cursed legendary blade" in inventory:
    print("*you defeated him but your sword almost killed you, the oldman stop that from happening*")
    print("Hey kid I will train you so you can master that sword, you can travel in 2 years")
if "Great Sword" in inventory:
    print("you were defeated and you only got 5 nicks on him")
    print("Come back to me when you train yourself and I will teach you the way of HAKI")

def ending1():
 if "cursed legendary blade" in inventory:
  response4 = input("do want to learn conquers haki first, yes or no?:  ")
  response4 = responseValidator(response4)
  return response4

def chioce4(response4):
  if "cursed legendary blade" in inventory:
    if response4 == "yes":
      print("Nice you were able to master every haki")
    else:
      print("You have fully master a ryou haki and future sight, later in time you can gain it...")

def main4():
  response4 = ending1()
  chioce4(response4)

main4()

def ending2():
  if "cursed legendary blade" in inventory:
    response5 = input("after the 2 years you have created a crew, you find out that a island you have arrived at have slavey training and you find out who's run the trading, do you kill the celestial dragons(the owner)? if you do the Marines will come after you becomes thats a crime and your a pirate, yes or no?:   ")
    response5 = responseValidator(response5)
    return response5

def chioce5(response5):
  if "cursed legendary blade" in inventory:
    if response5 == "yes":
      print("The world is happy that you're a good pirate, in this corrupt world but the marine set your bounty to 3 Billion since you were able to defeated a admire")
    else:
      print("you contiune the seas and gain coquers haki if u hadn't ")

def main5():
  response5 = ending2()
  chioce5(response5)

main5()

def ending3():
 if "cursed legendary blade" in inventory:
  response6 = input("You have traveled across the world, wanting become king of the Priates you found the nika nika no mi and you ate it, but you saw love do you chase?")
  response6 = responseValidator(response6)
  return response6

def chioce6(response6):
  if "cursed legendary blade" in inventory:
    if response6 == "yes":
      print("you have still by her side by 20 years, leaving your crew, while people were dying and more slaves has up in numbers by the celestial dragons but u decide to end it and get the crew back")
    else:
      print("you traveled to the holy land to end the war in the worlds corruption")

def main6():
  response6 = ending3()
  chioce6(response6)

main6()

def ending4():
 if "cursed legendary blade" in inventory:
  response7 = input("you get there, to hear that celestial dragons are the less problems you hear about the Holy knights, The 5 Elders, and IMU and defeated them all but IMU. Do you allow the celestial dragons to starve to death by stealing all there food for your rest? yes or no?:  ")
  response7 = responseValidator(response7)
  return response7

def chioce7(response7):
  if "cursed legendary blade" in inventory:
    if response7 == "yes":
      print("The slaves love to see that happened and you have defeated IMU and free the world and you have became Priate King, Thank you for playing! (Priate King Ending)")
    else:
      print("IMU was defeated but you barely got a some of your crew died leaving you regret of not taking the food to save more lives and get justice but the world is now free and you have became Priate King, Thank you for playing! (Priate King Ending)")

def main7():
  response7 = ending4()
  chioce7(response7)

main7()

if "cursed legendary blade" in inventory:
  inventory = []
  inventory.append("Title of Priate King")
  print("You have the Title of Priate King!")
pass

#Thank you for Playing, rate this in X for the feedback

def ending5():
 if "Great Sword" in inventory:
  response8 = input("Sword haki first, yes or no?:  ")
  response8 = responseValidator(response8)
  return response8

def chioce8(response8):
 if "Great Sword" in inventory:
  if response8 == "yes":
    print("Nice you were able to master the best haki")
  else:
    print("Unlocked body haki but you dont have kings sword haki")

def main8():
  response8 = ending5()
  chioce8(response8)

main8()

def ending6():
 if "Great Sword" in inventory:
  response9 = input("after the a 3 years you have join a crew, a celestial dragons takes you do you kill him on the spot, yes or no?:   ")
  response9 = responseValidator(response9)
  return response9

def chioce9(response9):
 if "Great Sword" in inventory:
  if response9 == "yes":
    print("The world is happy that you're a good pirate and allowing yourself to be free, in this corrupt world but the marine set your bounty to 2 Billion since you were able to defeat a CP0 member, you wanting to free the help from your blade")
  else:
    print("you were a slave for 2 weeks, your crew saved you leaving you wanting to help the world from your blade")

def main9():
  response9 = ending6()
  chioce9(response9)

main9()

def ending7():
 if "Great Sword" in inventory:
  response10 = input("You have traveled across the world, The world's greatest swordsman, but you saw the man that has that title do you face him now? yes or no?:  ")
  response10 = responseValidator(response10)
  return response10

def chioce10(response10):
 if "Great Sword" in inventory:
  if response10 == "yes":
    print("u have been defeated promising him that you will take that title at the end of your travels, so you fully recover and you traveled to the holy land to end the war in the worlds corruption")
  else:
    print(" look past him and you traveled to the holy land to end the war in the worlds corruption")

def main10():
  response10 = ending7()
  chioce10(response10)

main10()

def ending8():
 if "Great Sword" in inventory:
  response11 = input("you get there, to hear that celestial dragons are the less problems you hear about the Holy knights, The 5 Elders, and IMU and defeated them all but IMU. Do you allow the celestial dragons to starve to death by stealing all there food for your rest for the crew? yes or no?:  ")
  response11 = responseValidator(response11)
  return response11

def chioce11(response11):
 if "Great Sword" in inventory:
  if response11 == "yes":
    print("The slaves love to see that happened and your leader have defeated IMU, freeing the world and you have became The World's Greatest Swordsman by defeating the man in with the titled, Thank you for playing! (Swordsman Ending)")
  else:
    print("IMU was defeated but you barely got a some of your crew died and killing you to leaving you regret of not taking the food to save more lives and get justice but the world is now free and you have became The World's Greatest Swordsman in history, Thank you for playing! (Swordsman in death Ending)")

def main11():
  response11 = ending8()
  chioce11(response11)

main11()

if "Great Sword" in inventory:
  inventory = []
  inventory.append("Title of The World's Greatest Swordsman")
  print("You have the became The World's Greatest Swordsman!")
# Out:
# You approach a cave, do you enter? yes or no: no
# You kept moving and contined your normal life. Thank you for playing! jk you keep moving on
# you found a wicked blade, you pick it up ... you saw a portal do you enter? yes or no:  no
# A boulder forced you to jump in or you would have died
# cursed legendary blade. keep it? (yes/no): no
# You added a Great Sword and 10000000 Berries to your inventory!
# you crashed landed onto a nearby a village but your landing was slicence from trees ... the blade you have grabed from early turned into a cursed legendary blade do you keep it or sell it to a sword dealer in the nearby village?:  sell it
# you went to the sword dealer, buying a new great level sword and in the village and in it sold for 10 million Berries and you ask around for info about your current statues, you find a man that has travel around the world, you may ask him anything
# you were defeated and you only got 5 nicks on him
# ...
